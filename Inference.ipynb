# %%
from transformers import BertTokenizer, BertForMaskedLM
import torch
from transformers import AdamW
from tqdm import tqdm  
import random

from torch.utils.data import random_split

from torch.utils.data import DataLoader

from transformers import TrainingArguments
from transformers import Trainer

# %% [markdown]
# # BERT BASE uncased
# ## Loading BERT Tokenizer

# %%
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased',Fast = True)

# %% [markdown]
# ## Loading Pre Trained Model

# %%
model = BertForMaskedLM.from_pretrained('bert-base-uncased',return_dict=True)
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# # Data Pre Processing
# ## Loading File and sub sampling

# %%
with open('Roman_Urdu_Twitter.txt', 'r', encoding='utf-8') as fp:
    text = fp.read().split('\n')
sub_text = random.sample(text,101338)

# %% [markdown]
# ## Creating Tokens

# %%
inputs = tokenizer(sub_text, return_tensors='pt', max_length=64, truncation=True, padding='max_length')

# %%
torch.save(inputs,'inputs_sub_new.pt')

# %%
inputs = torch.load('inputs_sub_new.pt')

# %% [markdown]
# ## Creating Labels

# %%
inputs['labels'] = inputs.input_ids.detach().clone()

# %% [markdown]
# ## Masking

# %%
random_tensor = torch.rand(inputs['input_ids'].shape)

# %%
masked_tensor = (random_tensor < 0.15)*(inputs['input_ids'] != 101)*(inputs['input_ids'] != 102)*(inputs['input_ids'] != 0)

# %%
# getting all those indices from each row which are set to True, i.e. masked.
nonzeros_indices = []
for i in range(len(masked_tensor)):
    nonzeros_indices.append(torch.flatten(masked_tensor[i].nonzero()).tolist())

# %%
# setting the values at those indices to be a MASK token (103) for every row in the original input_ids.
for i in range(len(inputs['input_ids'])):
    inputs['input_ids'][i, nonzeros_indices[i]] = 103
    
# 101 CLS TOKEN  
# 103 MASK
# 102 SCP Token
# 0 PADDING TOKEN

# %% [markdown]
# ## Custom Dataset Class Pytorch

# %%
class RomanUrduDataset(torch.utils.data.Dataset):
    def __init__(self, encodings):
        self.encodings = encodings
    
    def __len__(self):
        return len(self.encodings['input_ids'])

    def __getitem__(self, index):
        input_ids = self.encodings['input_ids'][index]
        labels = self.encodings['labels'][index]
        attention_mask = self.encodings['attention_mask'][index]
        token_type_ids = self.encodings['token_type_ids'][index]
        return {
            'input_ids': input_ids,
            'labels': labels,
            'attention_mask': attention_mask,
            'token_type_ids': token_type_ids}

# %%
dataset = RomanUrduDataset(inputs)

# %% [markdown]
# ## Train and validation dataset split

# %%
train_size = int(0.9 * len(dataset))
val_size = len(dataset) - train_size

# %%
train_dataset, val_dataset = random_split(dataset, [train_size,val_size])

# %% [markdown]
# ## Hyperparameters

# %%
epochs = 10
batch_size = 12
#optimizer = AdamW(model.parameters(), lr=1e-5)

# %% [markdown]
# # Pytorch DataLoader

# %%
dataloader = DataLoader(
    dataset,
    batch_size=batch_size,
    shuffle=True
)

# %% [markdown]
# ### Device setting

# %%
model.to(torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu'))
# Out:
# device(type='cuda')

# %% [markdown]
# # Training using Hugging Face Trainer

# %%
args = TrainingArguments(
    output_dir='MLM/new/model',
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size= batch_size,
    num_train_epochs=epochs,
    logging_dir = 'MLM/new/log',
    evaluation_strategy="steps",
    logging_steps=1000,
    logging_first_step=True,
    save_steps=1000,
)

# %%
trainer = Trainer(
    model=model,
    args=args,
    train_dataset=train_dataset, 
    eval_dataset = val_dataset
)

# %%
results = trainer.train()
# Out:
# ***** Running training *****
#   Num examples = 91204
#   Num Epochs = 10
#   Instantaneous batch size per device = 12
#   Total train batch size (w. parallel, distributed & accumulation) = 12
#   Gradient Accumulation steps = 1
#   Total optimization steps = 76010
#     <div>
#
#       <progress value='76010' max='76010' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [76010/76010 19:23:30, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1000</td>
#       <td>0.400900</td>
#       <td>0.298398</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.292700</td>
#       <td>0.281184</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.286700</td>
#       <td>0.272883</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.273800</td>
#       <td>0.266143</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.267500</td>
#       <td>0.261040</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.263800</td>
#       <td>0.255184</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.264000</td>
#       <td>0.252878</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.241800</td>
#       <td>0.254567</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.217800</td>
#       <td>0.249827</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.222000</td>
#       <td>0.250390</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.222400</td>
#       <td>0.246560</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.220500</td>
#       <td>0.245904</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.222500</td>
#       <td>0.242915</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.213800</td>
#       <td>0.242358</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.214000</td>
#       <td>0.240630</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.182200</td>
#       <td>0.253744</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.175000</td>
#       <td>0.250242</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.173400</td>
#       <td>0.247091</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.181300</td>
#       <td>0.249922</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.178300</td>
#       <td>0.245956</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.178500</td>
#       <td>0.243929</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.181300</td>
#       <td>0.246133</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.169300</td>
#       <td>0.254548</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.136800</td>
#       <td>0.256750</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.140400</td>
#       <td>0.258356</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.141200</td>
#       <td>0.257066</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.142300</td>
#       <td>0.257047</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.142900</td>
#       <td>0.253687</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.146900</td>
#       <td>0.254678</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.143400</td>
#       <td>0.253414</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.119600</td>
#       <td>0.267697</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.107600</td>
#       <td>0.265833</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.108000</td>
#       <td>0.267050</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.111500</td>
#       <td>0.266702</td>
#     </tr>
#     <tr>
#       <td>35000</td>
#       <td>0.111700</td>
#       <td>0.265083</td>
#     </tr>
#     <tr>
#       <td>36000</td>
#       <td>0.111000</td>
#       <td>0.267339</td>
#     </tr>
#     <tr>
#       <td>37000</td>
#       <td>0.113000</td>
#       <td>0.267095</td>
#     </tr>
#     <tr>
#       <td>38000</td>
#       <td>0.115000</td>
#       <td>0.264267</td>
#     </tr>
#     <tr>
#       <td>39000</td>
#       <td>0.080600</td>
#       <td>0.278440</td>
#     </tr>
#     <tr>
#       <td>40000</td>
#       <td>0.082800</td>
#       <td>0.276889</td>
#     </tr>
#     <tr>
#       <td>41000</td>
#       <td>0.081700</td>
#       <td>0.279694</td>
#     </tr>
#     <tr>
#       <td>42000</td>
#       <td>0.083200</td>
#       <td>0.278863</td>
#     </tr>
#     <tr>
#       <td>43000</td>
#       <td>0.084700</td>
#       <td>0.279599</td>
#     </tr>
#     <tr>
#       <td>44000</td>
#       <td>0.087200</td>
#       <td>0.278071</td>
#     </tr>
#     <tr>
#       <td>45000</td>
#       <td>0.085900</td>
#       <td>0.277301</td>
#     </tr>
#     <tr>
#       <td>46000</td>
#       <td>0.074000</td>
#       <td>0.286343</td>
#     </tr>
#     <tr>
#       <td>47000</td>
#       <td>0.059000</td>
#       <td>0.288906</td>
#     </tr>
#     <tr>
#       <td>48000</td>
#       <td>0.061100</td>
#       <td>0.289052</td>
#     </tr>
#     <tr>
#       <td>49000</td>
#       <td>0.063100</td>
#       <td>0.287995</td>
#     </tr>
#     <tr>
#       <td>50000</td>
#       <td>0.062100</td>
#       <td>0.289096</td>
#     </tr>
#     <tr>
#       <td>51000</td>
#       <td>0.063600</td>
#       <td>0.288393</td>
#     </tr>
#     <tr>
#       <td>52000</td>
#       <td>0.063600</td>
#       <td>0.288781</td>
#     </tr>
#     <tr>
#       <td>53000</td>
#       <td>0.063200</td>
#       <td>0.289336</td>
#     </tr>
#     <tr>
#       <td>54000</td>
#       <td>0.046200</td>
#       <td>0.295936</td>
#     </tr>
#     <tr>
#       <td>55000</td>
#       <td>0.044300</td>
#       <td>0.296394</td>
#     </tr>
#     <tr>
#       <td>56000</td>
#       <td>0.043800</td>
#       <td>0.297084</td>
#     </tr>
#     <tr>
#       <td>57000</td>
#       <td>0.045900</td>
#       <td>0.297423</td>
#     </tr>
#     <tr>
#       <td>58000</td>
#       <td>0.046000</td>
#       <td>0.297073</td>
#     </tr>
#     <tr>
#       <td>59000</td>
#       <td>0.045000</td>
#       <td>0.298052</td>
#     </tr>
#     <tr>
#       <td>60000</td>
#       <td>0.046800</td>
#       <td>0.298374</td>
#     </tr>
#     <tr>
#       <td>61000</td>
#       <td>0.043700</td>
#       <td>0.300037</td>
#     </tr>
#     <tr>
#       <td>62000</td>
#       <td>0.031800</td>
#       <td>0.301672</td>
#     </tr>
#     <tr>
#       <td>63000</td>
#       <td>0.032100</td>
#       <td>0.302364</td>
#     </tr>
#     <tr>
#       <td>64000</td>
#       <td>0.033600</td>
#       <td>0.302526</td>
#     </tr>
#     <tr>
#       <td>65000</td>
#       <td>0.033900</td>
#       <td>0.303180</td>
#     </tr>
#     <tr>
#       <td>66000</td>
#       <td>0.033400</td>
#       <td>0.303276</td>
#     </tr>
#     <tr>
#       <td>67000</td>
#       <td>0.034100</td>
#       <td>0.303614</td>
#     </tr>
#     <tr>
#       <td>68000</td>
#       <td>0.033200</td>
#       <td>0.302617</td>
#     </tr>
#     <tr>
#       <td>69000</td>
#       <td>0.029800</td>
#       <td>0.305025</td>
#     </tr>
#     <tr>
#       <td>70000</td>
#       <td>0.025400</td>
#       <td>0.305400</td>
#     </tr>
#     <tr>
#       <td>71000</td>
#       <td>0.024900</td>
#       <td>0.306016</td>
#     </tr>
#     <tr>
#       <td>72000</td>
#       <td>0.025700</td>
#       <td>0.305738</td>
#     </tr>
#     <tr>
#       <td>73000</td>
#       <td>0.025300</td>
#       <td>0.305793</td>
#     </tr>
#     <tr>
#       <td>74000</td>
#       <td>0.025900</td>
#       <td>0.306015</td>
#     </tr>
#     <tr>
#       <td>75000</td>
#       <td>0.025000</td>
#       <td>0.306275</td>
#     </tr>
#     <tr>
#       <td>76000</td>
#       <td>0.025100</td>
#       <td>0.306176</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-1000
# Configuration saved in MLM/new/model\checkpoint-1000\config.json
# Model weights saved in MLM/new/model\checkpoint-1000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-2000
# Configuration saved in MLM/new/model\checkpoint-2000\config.json
# Model weights saved in MLM/new/model\checkpoint-2000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-3000
# Configuration saved in MLM/new/model\checkpoint-3000\config.json
# Model weights saved in MLM/new/model\checkpoint-3000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-4000
# Configuration saved in MLM/new/model\checkpoint-4000\config.json
# Model weights saved in MLM/new/model\checkpoint-4000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-5000
# Configuration saved in MLM/new/model\checkpoint-5000\config.json
# Model weights saved in MLM/new/model\checkpoint-5000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-6000
# Configuration saved in MLM/new/model\checkpoint-6000\config.json
# Model weights saved in MLM/new/model\checkpoint-6000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-7000
# Configuration saved in MLM/new/model\checkpoint-7000\config.json
# Model weights saved in MLM/new/model\checkpoint-7000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-8000
# Configuration saved in MLM/new/model\checkpoint-8000\config.json
# Model weights saved in MLM/new/model\checkpoint-8000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-9000
# Configuration saved in MLM/new/model\checkpoint-9000\config.json
# Model weights saved in MLM/new/model\checkpoint-9000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-10000
# Configuration saved in MLM/new/model\checkpoint-10000\config.json
# Model weights saved in MLM/new/model\checkpoint-10000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-11000
# Configuration saved in MLM/new/model\checkpoint-11000\config.json
# Model weights saved in MLM/new/model\checkpoint-11000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-12000
# Configuration saved in MLM/new/model\checkpoint-12000\config.json
# Model weights saved in MLM/new/model\checkpoint-12000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-13000
# Configuration saved in MLM/new/model\checkpoint-13000\config.json
# Model weights saved in MLM/new/model\checkpoint-13000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-14000
# Configuration saved in MLM/new/model\checkpoint-14000\config.json
# Model weights saved in MLM/new/model\checkpoint-14000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-15000
# Configuration saved in MLM/new/model\checkpoint-15000\config.json
# Model weights saved in MLM/new/model\checkpoint-15000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-16000
# Configuration saved in MLM/new/model\checkpoint-16000\config.json
# Model weights saved in MLM/new/model\checkpoint-16000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-17000
# Configuration saved in MLM/new/model\checkpoint-17000\config.json
# Model weights saved in MLM/new/model\checkpoint-17000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-18000
# Configuration saved in MLM/new/model\checkpoint-18000\config.json
# Model weights saved in MLM/new/model\checkpoint-18000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-19000
# Configuration saved in MLM/new/model\checkpoint-19000\config.json
# Model weights saved in MLM/new/model\checkpoint-19000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-20000
# Configuration saved in MLM/new/model\checkpoint-20000\config.json
# Model weights saved in MLM/new/model\checkpoint-20000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-21000
# Configuration saved in MLM/new/model\checkpoint-21000\config.json
# Model weights saved in MLM/new/model\checkpoint-21000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-22000
# Configuration saved in MLM/new/model\checkpoint-22000\config.json
# Model weights saved in MLM/new/model\checkpoint-22000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-23000
# Configuration saved in MLM/new/model\checkpoint-23000\config.json
# Model weights saved in MLM/new/model\checkpoint-23000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-24000
# Configuration saved in MLM/new/model\checkpoint-24000\config.json
# Model weights saved in MLM/new/model\checkpoint-24000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-25000
# Configuration saved in MLM/new/model\checkpoint-25000\config.json
# Model weights saved in MLM/new/model\checkpoint-25000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-26000
# Configuration saved in MLM/new/model\checkpoint-26000\config.json
# Model weights saved in MLM/new/model\checkpoint-26000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-27000
# Configuration saved in MLM/new/model\checkpoint-27000\config.json
# Model weights saved in MLM/new/model\checkpoint-27000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-28000
# Configuration saved in MLM/new/model\checkpoint-28000\config.json
# Model weights saved in MLM/new/model\checkpoint-28000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-29000
# Configuration saved in MLM/new/model\checkpoint-29000\config.json
# Model weights saved in MLM/new/model\checkpoint-29000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-30000
# Configuration saved in MLM/new/model\checkpoint-30000\config.json
# Model weights saved in MLM/new/model\checkpoint-30000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-31000
# Configuration saved in MLM/new/model\checkpoint-31000\config.json
# Model weights saved in MLM/new/model\checkpoint-31000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-32000
# Configuration saved in MLM/new/model\checkpoint-32000\config.json
# Model weights saved in MLM/new/model\checkpoint-32000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-33000
# Configuration saved in MLM/new/model\checkpoint-33000\config.json
# Model weights saved in MLM/new/model\checkpoint-33000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-34000
# Configuration saved in MLM/new/model\checkpoint-34000\config.json
# Model weights saved in MLM/new/model\checkpoint-34000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-35000
# Configuration saved in MLM/new/model\checkpoint-35000\config.json
# Model weights saved in MLM/new/model\checkpoint-35000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-36000
# Configuration saved in MLM/new/model\checkpoint-36000\config.json
# Model weights saved in MLM/new/model\checkpoint-36000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-37000
# Configuration saved in MLM/new/model\checkpoint-37000\config.json
# Model weights saved in MLM/new/model\checkpoint-37000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-38000
# Configuration saved in MLM/new/model\checkpoint-38000\config.json
# Model weights saved in MLM/new/model\checkpoint-38000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-39000
# Configuration saved in MLM/new/model\checkpoint-39000\config.json
# Model weights saved in MLM/new/model\checkpoint-39000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-40000
# Configuration saved in MLM/new/model\checkpoint-40000\config.json
# Model weights saved in MLM/new/model\checkpoint-40000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-41000
# Configuration saved in MLM/new/model\checkpoint-41000\config.json
# Model weights saved in MLM/new/model\checkpoint-41000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-42000
# Configuration saved in MLM/new/model\checkpoint-42000\config.json
# Model weights saved in MLM/new/model\checkpoint-42000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-43000
# Configuration saved in MLM/new/model\checkpoint-43000\config.json
# Model weights saved in MLM/new/model\checkpoint-43000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-44000
# Configuration saved in MLM/new/model\checkpoint-44000\config.json
# Model weights saved in MLM/new/model\checkpoint-44000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-45000
# Configuration saved in MLM/new/model\checkpoint-45000\config.json
# Model weights saved in MLM/new/model\checkpoint-45000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-46000
# Configuration saved in MLM/new/model\checkpoint-46000\config.json
# Model weights saved in MLM/new/model\checkpoint-46000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-47000
# Configuration saved in MLM/new/model\checkpoint-47000\config.json
# Model weights saved in MLM/new/model\checkpoint-47000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-48000
# Configuration saved in MLM/new/model\checkpoint-48000\config.json
# Model weights saved in MLM/new/model\checkpoint-48000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-49000
# Configuration saved in MLM/new/model\checkpoint-49000\config.json
# Model weights saved in MLM/new/model\checkpoint-49000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-50000
# Configuration saved in MLM/new/model\checkpoint-50000\config.json
# Model weights saved in MLM/new/model\checkpoint-50000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-51000
# Configuration saved in MLM/new/model\checkpoint-51000\config.json
# Model weights saved in MLM/new/model\checkpoint-51000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-52000
# Configuration saved in MLM/new/model\checkpoint-52000\config.json
# Model weights saved in MLM/new/model\checkpoint-52000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-53000
# Configuration saved in MLM/new/model\checkpoint-53000\config.json
# Model weights saved in MLM/new/model\checkpoint-53000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-54000
# Configuration saved in MLM/new/model\checkpoint-54000\config.json
# Model weights saved in MLM/new/model\checkpoint-54000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-55000
# Configuration saved in MLM/new/model\checkpoint-55000\config.json
# Model weights saved in MLM/new/model\checkpoint-55000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-56000
# Configuration saved in MLM/new/model\checkpoint-56000\config.json
# Model weights saved in MLM/new/model\checkpoint-56000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-57000
# Configuration saved in MLM/new/model\checkpoint-57000\config.json
# Model weights saved in MLM/new/model\checkpoint-57000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-58000
# Configuration saved in MLM/new/model\checkpoint-58000\config.json
# Model weights saved in MLM/new/model\checkpoint-58000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-59000
# Configuration saved in MLM/new/model\checkpoint-59000\config.json
# Model weights saved in MLM/new/model\checkpoint-59000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-60000
# Configuration saved in MLM/new/model\checkpoint-60000\config.json
# Model weights saved in MLM/new/model\checkpoint-60000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-61000
# Configuration saved in MLM/new/model\checkpoint-61000\config.json
# Model weights saved in MLM/new/model\checkpoint-61000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-62000
# Configuration saved in MLM/new/model\checkpoint-62000\config.json
# Model weights saved in MLM/new/model\checkpoint-62000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-63000
# Configuration saved in MLM/new/model\checkpoint-63000\config.json
# Model weights saved in MLM/new/model\checkpoint-63000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-64000
# Configuration saved in MLM/new/model\checkpoint-64000\config.json
# Model weights saved in MLM/new/model\checkpoint-64000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-65000
# Configuration saved in MLM/new/model\checkpoint-65000\config.json
# Model weights saved in MLM/new/model\checkpoint-65000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-66000
# Configuration saved in MLM/new/model\checkpoint-66000\config.json
# Model weights saved in MLM/new/model\checkpoint-66000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-67000
# Configuration saved in MLM/new/model\checkpoint-67000\config.json
# Model weights saved in MLM/new/model\checkpoint-67000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-68000
# Configuration saved in MLM/new/model\checkpoint-68000\config.json
# Model weights saved in MLM/new/model\checkpoint-68000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-69000
# Configuration saved in MLM/new/model\checkpoint-69000\config.json
# Model weights saved in MLM/new/model\checkpoint-69000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-70000
# Configuration saved in MLM/new/model\checkpoint-70000\config.json
# Model weights saved in MLM/new/model\checkpoint-70000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-71000
# Configuration saved in MLM/new/model\checkpoint-71000\config.json
# Model weights saved in MLM/new/model\checkpoint-71000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-72000
# Configuration saved in MLM/new/model\checkpoint-72000\config.json
# Model weights saved in MLM/new/model\checkpoint-72000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-73000
# Configuration saved in MLM/new/model\checkpoint-73000\config.json
# Model weights saved in MLM/new/model\checkpoint-73000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-74000
# Configuration saved in MLM/new/model\checkpoint-74000\config.json
# Model weights saved in MLM/new/model\checkpoint-74000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-75000
# Configuration saved in MLM/new/model\checkpoint-75000\config.json
# Model weights saved in MLM/new/model\checkpoint-75000\pytorch_model.bin
# ***** Running Evaluation *****
#   Num examples = 10134
#   Batch size = 12
# Saving model checkpoint to MLM/new/model\checkpoint-76000
# Configuration saved in MLM/new/model\checkpoint-76000\config.json
# Model weights saved in MLM/new/model\checkpoint-76000\pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)

# %%
results
# Out:
# TrainOutput(global_step=76010, training_loss=0.11892884478704221, metrics={'train_runtime': 69813.9237, 'train_samples_per_second': 13.064, 'train_steps_per_second': 1.089, 'total_flos': 3.0006664683264e+16, 'train_loss': 0.11892884478704221, 'epoch': 10.0})

# %%
type(results)
# Out:
# transformers.trainer_utils.TrainOutput
